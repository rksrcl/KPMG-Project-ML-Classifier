# %% [markdown]
# # Data Cleaning and Preprocessing for Donor Information
#
# This notebook focuses on cleaning and preprocessing donor data from the `combined_donor_info.csv` file. The objective is to handle missing values, reduce features that are mostly missing, and prepare the data for further analysis and machine learning tasks.

# %%
# Importing libraries 
# We will primarily use `pandas` for data manipulation and cleaning.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('combined_donor_info.csv')

# Display the first few rows
df.head()
# Out:
#    Masked Account ID Maked Primary Campaign       Stage Account Type  \
# 0                  1                    NaN  Closed Won    Household
# 1                  1                    NaN  Closed Won    Household
# 2                  1                    NaN  Closed Won    Household
# 3                  1                    NaN  Closed Won    Household
# 4                  1                    NaN  Closed Won    Household
#
#   Billing Zip/Postal Code Fiscal Period Close Date    Amount     ZCTA    Year  \
# 0                   90069       Q3-2022   7/5/2022  200000.0  90069.0  2021.0
# 1                   90069       Q3-2022   7/5/2022  200000.0  90069.0  2020.0
# 2                   90069       Q3-2022   7/5/2022  200000.0  90069.0  2019.0
# 3                   90069       Q3-2023  7/14/2023  200000.0  90069.0  2021.0
# 4                   90069       Q3-2023  7/14/2023  200000.0  90069.0  2020.0
#
#    ...  Public Transport  Worked from Home  Health Ins Pop  Health Ins  \
# 0  ...             333.0            3432.0         20185.0     19509.0
# 1  ...             241.0            2589.0         20035.0     19339.0
# 2  ...             266.0            1963.0         20230.0     19348.0
# 3  ...             333.0            3432.0         20185.0     19509.0
# 4  ...             241.0            2589.0         20035.0     19339.0
#
#   No Health Ins Labor Population Armed Forces Employed Unemployed  \
# 0         676.0          19125.0          0.0  14080.0     1124.0
# 1         696.0          19017.0          0.0  14119.0      910.0
# 2         882.0          19254.0          0.0  14444.0      738.0
# 3         676.0          19125.0          0.0  14080.0     1124.0
# 4         696.0          19017.0          0.0  14119.0      910.0
#
#   Not in Labor Force
# 0             3921.0
# 1             3988.0
# 2             4072.0
# 3             3921.0
# 4             3988.0
#
# [5 rows x 87 columns]

# %% [markdown]
# ## Checking Data Types and Missing Values
#
# We use `.info()` to examine the data types and number of non-null values for each feature, and `.describe()` for a statistical summary of numerical features. Additionally, we calculate the percentage of missing values in each column.

# %%
# Check the data types and non-null counts for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6290 entries, 0 to 6289
# Data columns (total 87 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Masked Account ID                  6290 non-null   int64
#  1   Maked Primary Campaign             4504 non-null   object
#  2   Stage                              6290 non-null   object
#  3   Account Type                       6290 non-null   object
#  4   Billing Zip/Postal Code            5789 non-null   object
#  5   Fiscal Period                      6290 non-null   object
#  6   Close Date                         6290 non-null   object
#  7   Amount                             6290 non-null   float64
#  8   ZCTA                               5662 non-null   float64
#  9   Year                               4780 non-null   float64
#  10  Pop                                4780 non-null   float64
#  11  Households                         4780 non-null   float64
#  12  HH Income                          4780 non-null   float64
#  13  Education Years                    4780 non-null   float64
#  14  Minority %                         4780 non-null   object
#  15  Poor %                             4780 non-null   object
#  16  Poor Family %                      4780 non-null   object
#  17  Car or Van %                       4780 non-null   object
#  18  Public Transport %                 4780 non-null   object
#  19  Health Ins %                       4780 non-null   object
#  20  No Health Ins %                    4780 non-null   object
#  21  Unemployed %                       4780 non-null   object
#  22  Employed %                         4780 non-null   object
#  23  Armed Forces %                     4780 non-null   object
#  24  Not in Labor Force %               4780 non-null   object
#  25  Under 10 %                         4780 non-null   object
#  26  Under 35 %                         4780 non-null   object
#  27  Over 65 %                          4780 non-null   object
#  28  Over 85 %                          4780 non-null   object
#  29  High school %                      4780 non-null   object
#  30  College %                          4780 non-null   object
#  31  0-50k %                            4780 non-null   object
#  32  50-100k %                          4780 non-null   object
#  33  100-150k %                         4780 non-null   object
#  34  150-200k %                         4780 non-null   object
#  35  200k+ %                            4780 non-null   object
#  36  Minority                           4780 non-null   float64
#  37  Under 10                           4780 non-null   float64
#  38  Under 35                           4780 non-null   float64
#  39  Over 65                            4780 non-null   float64
#  40  Over 85                            4780 non-null   float64
#  41  Male 10-14                         4780 non-null   float64
#  42  Male 15-17                         4780 non-null   float64
#  43  Male 18-19                         4780 non-null   float64
#  44  Male 20                            4780 non-null   float64
#  45  Male 21                            4780 non-null   float64
#  46  Male 22-24                         4780 non-null   float64
#  47  Male 25-29                         4780 non-null   float64
#  48  Male 30-34                         4780 non-null   float64
#  49  Female 10-14                       4780 non-null   float64
#  50  Female 15-17                       4780 non-null   float64
#  51  Female 18-19                       4780 non-null   float64
#  52  Female 20                          4780 non-null   float64
#  53  Female 21                          4780 non-null   float64
#  54  Female 22-24                       4780 non-null   float64
#  55  Female 25-29                       4780 non-null   float64
#  56  Female 30-34                       4780 non-null   float64
#  57  Ed Pop                             4780 non-null   float64
#  58  Less than High School              4780 non-null   float64
#  59  High school                        4780 non-null   float64
#  60  GED                                4780 non-null   float64
#  61  Some college to Associates Degree  4780 non-null   float64
#  62  Bachelor's Degree or Higher        4780 non-null   float64
#  63  $0-25k                             4780 non-null   float64
#  64  $25-50k                            4780 non-null   float64
#  65  $50-75k                            4780 non-null   float64
#  66  $75-100k                           4780 non-null   float64
#  67  $100-125k                          4780 non-null   float64
#  68  $125-150k                          4780 non-null   float64
#  69  $150-200k                          4780 non-null   float64
#  70  $200k+                             4780 non-null   float64
#  71  Poverty Pop                        4780 non-null   float64
#  72  Poor                               4780 non-null   float64
#  73  Poor Family                        4780 non-null   float64
#  74  Transport Pop                      4780 non-null   float64
#  75  Car or Van                         4780 non-null   float64
#  76  Carpool                            4780 non-null   float64
#  77  Public Transport                   4780 non-null   float64
#  78  Worked from Home                   4780 non-null   float64
#  79  Health Ins Pop                     4780 non-null   float64
#  80  Health Ins                         4780 non-null   float64
#  81  No Health Ins                      4780 non-null   float64
#  82  Labor Population                   4780 non-null   float64
#  83  Armed Forces                       4780 non-null   float64
#  84  Employed                           4780 non-null   float64
#  85  Unemployed                         4780 non-null   float64
#  86  Not in Labor Force                 4780 non-null   float64
# dtypes: float64(58), int64(1), object(28)
# memory usage: 4.2+ MB

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#        Masked Account ID        Amount          ZCTA         Year  \
# count        6290.000000  6.290000e+03   5662.000000  4780.000000
# mean          472.245628  4.872656e+03  86845.853762  2020.005858
# std           386.745184  1.102559e+05  14516.508915     0.817756
# min             1.000000 -2.000000e+02  10002.000000  2019.000000
# 25%           133.000000  1.000000e+02  90046.000000  2019.000000
# 50%           359.000000  2.500000e+02  90074.000000  2020.000000
# 75%           777.750000  1.000000e+03  91031.000000  2021.000000
# max          1321.000000  5.000029e+06  98607.000000  2021.000000
#
#                  Pop    Households    HH Income  Education Years  \
# count    4780.000000   4780.000000  4780.000000      4780.000000
# mean    28881.300418  12046.998326   111.919718        15.002583
# std     16938.925375   6997.016492    24.481824         1.851160
# min         0.000000      0.000000     0.000000         0.000000
# 25%     15292.000000   5887.000000    99.483534        14.783736
# 50%     25988.000000  11775.000000   111.718232        15.497020
# 75%     39755.000000  16375.000000   128.312519        15.917162
# max    100225.000000  38263.000000   162.891641        16.751562
#
#            Minority      Under 10  ...  Public Transport  Worked from Home  \
# count   4780.000000   4780.000000  ...       4780.000000       4780.000000
# mean    9451.154603   2873.945816  ...        783.567992       2134.437657
# std     9997.166591   1880.665073  ...       1799.634002       1447.170498
# min        0.000000      0.000000  ...          0.000000          0.000000
# 25%     2555.000000   1524.000000  ...         76.000000       1017.000000
# 50%     6354.500000   2932.000000  ...        374.000000       1837.000000
# 75%    12812.000000   3747.000000  ...        626.250000       3045.000000
# max    78022.000000  16452.000000  ...      26134.000000      10835.000000
#
#        Health Ins Pop    Health Ins  No Health Ins  Labor Population  \
# count     4780.000000   4780.000000    4780.000000       4780.000000
# mean     28770.460042  27127.008159    1643.451883      24276.261925
# std      16841.919092  15401.362681    2108.157507      14425.163945
# min          0.000000      0.000000       0.000000          0.000000
# 25%      15214.000000  14755.000000     529.000000      12641.250000
# 50%      25901.000000  25015.000000     807.500000      21542.000000
# 75%      39568.000000  35987.000000    2039.750000      32305.000000
# max     100146.000000  92505.000000   15502.000000      75511.000000
#
#        Armed Forces      Employed   Unemployed  Not in Labor Force
# count   4780.000000   4780.000000  4780.000000         4780.000000
# mean      19.048954  15465.512134   900.946653         7890.754184
# std       50.577627   9690.622819   717.243955         4827.012112
# min        0.000000      0.000000     0.000000            0.000000
# 25%        0.000000   7576.000000   356.000000         3924.000000
# 50%        0.000000  14259.000000   762.000000         7203.000000
# 75%       21.000000  20221.000000  1234.000000        10126.000000
# max      799.000000  55321.000000  4404.000000        34013.000000
#
# [8 rows x 59 columns]

# %%
# Percentage of missing values in each column
missing_values = df.isnull().mean() * 100
missing_values
# Out:
# Masked Account ID           0.000000
# Maked Primary Campaign     28.394277
# Stage                       0.000000
# Account Type                0.000000
# Billing Zip/Postal Code     7.965024
#                              ...
# Labor Population           24.006359
# Armed Forces               24.006359
# Employed                   24.006359
# Unemployed                 24.006359
# Not in Labor Force         24.006359
# Length: 87, dtype: float64

# %%
## Identify Features with Too Many Missing Values
# Identify features with more than 80% missing values, which can potentially be removed since they do not provide much useful information.
features_to_consider_removing = missing_values[missing_values > 80].index.tolist()
features_to_consider_removing
# Out:
# []

# %% [markdown]
# ## Handling Missing Data
#
# For categorical features, we fill missing values with the mode (most frequent value). For numerical features, we use the mean to replace missing values to avoid the impact of outliers.

# %%
# Create a copy of the original DataFrame for cleaning
df_copy = df.copy()

# Fill missing values appropriately
for column in df_copy.columns:
    if df_copy[column].dtype == 'object':  # Categorical data
        # Fill missing values with mode for categorical data
        df_copy[column] = df_copy[column].fillna(df_copy[column].mode()[0])
    else:  # Numerical data
        # Fill missing values with mean for numerical data
        df_copy[column] = df_copy[column].fillna(df_copy[column].mean())

# %%
# Verify if all missing values are handled
missing_values = df_copy.isnull().mean() * 100
missing_values
# Out:
# Masked Account ID          0.0
# Maked Primary Campaign     0.0
# Stage                      0.0
# Account Type               0.0
# Billing Zip/Postal Code    0.0
#                           ...
# Labor Population           0.0
# Armed Forces               0.0
# Employed                   0.0
# Unemployed                 0.0
# Not in Labor Force         0.0
# Length: 87, dtype: float64

# %%
# Additional Notes from Maker Day 10.5.24
# count how many missing values in each column compared to total in different row
# user - row
# column - feature
# if 80% of users didn't have feature info, can reduce


# if too many missing values - may remove feature altogether

# kmeans clustering, see if features are similar & try to make predictions
# missing values - mean, mode, median - depends on how data looks like

# look @ each column, try to preprocess it :) :(((
# find numbers and see what want to remove

# pca - reduces number of features (dimensionaliy reduction)

# %% [markdown]
# ## Outliers

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(df_copy['Amount'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Donation Amounts')
plt.xlabel('Donation Amount')
plt.ylabel('Frequency')
plt.show()

# %%
df['Amount'] = np.log1p(df['Amount'])
plt.figure(figsize=(10, 6))
plt.hist(df_copy['Amount'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Log Donation Amounts')
plt.xlabel('Log of Donation Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Users/jc/predborrowersenv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Step 1: Set the threshold at the 95th percentile of the 'Amount' column
threshold = df_copy['Amount'].quantile(0.95)

# Step 2: Create the 'large_donation_flag' column
df_copy['large_donation_flag'] = (df_copy['Amount'] > threshold).astype(int)

# Step 3: Count the number of large donations
large_donations_count = df_copy[df_copy['large_donation_flag'] == 1].shape[0]  # This will give the count of rows

# Print the result
print(f"Number of large donations (above the 95th percentile): {large_donations_count}")
# Out:
# Number of large donations (above the 95th percentile): 257

# %%
df_copy.columns
# Out:
# Index(['Masked Account ID', 'Maked Primary Campaign', 'Stage', 'Account Type',
#        'Billing Zip/Postal Code', 'Fiscal Period', 'Close Date', 'Amount',
#        'ZCTA', 'Year', 'Pop', 'Households', 'HH Income', 'Education Years',
#        'Minority %', 'Poor %', 'Poor Family %', 'Car or Van %',
#        'Public Transport %', 'Health Ins %', 'No Health Ins %', 'Unemployed %',
#        'Employed %', 'Armed Forces %', 'Not in Labor Force %', 'Under 10 %',
#        'Under 35 %', 'Over 65 %', 'Over 85 %', 'High school %', 'College %',
#        '0-50k %', '50-100k %', '100-150k %', '150-200k %', '200k+ %',
#        'Minority', 'Under 10', 'Under 35', 'Over 65', 'Over 85', 'Male 10-14',
#        'Male 15-17', 'Male 18-19', 'Male 20', 'Male 21', 'Male 22-24',
#        'Male 25-29', 'Male 30-34', 'Female 10-14', 'Female 15-17',
#        'Female 18-19', 'Female 20', 'Female 21', 'Female 22-24',
#        'Female 25-29', 'Female 30-34', 'Ed Pop', 'Less than High School',
#        'High school', 'GED', 'Some college to Associates Degree',
#        'Bachelor's Degree or Higher', '$0-25k', '$25-50k', '$50-75k',
#        '$75-100k', '$100-125k', '$125-150k', '$150-200k', '$200k+',
#        'Poverty Pop', 'Poor', 'Poor Family', 'Transport Pop', 'Car or Van',
#        'Carpool', 'Public Transport', 'Worked from Home', 'Health Ins Pop',
#        'Health Ins', 'No Health Ins', 'Labor Population', 'Armed Forces',
#        'Employed', 'Unemployed', 'Not in Labor Force', 'large_donation_flag'],
#       dtype='object')

# %%
df_copy['Female 15-17']
# Out:
# 0        64.000000
# 1        96.000000
# 2       100.000000
# 3        64.000000
# 4        96.000000
#            ...
# 6285    411.739331
# 6286    411.739331
# 6287    910.000000
# 6288    935.000000
# 6289    920.000000
# Name: Female 15-17, Length: 6290, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# Define numerical columns to scale
numerical_columns = ['Amount', 'Pop', 'Households', 'HH Income', 'Education Years']

# Initialize the scaler and fit-transform the numerical columns
scaler = StandardScaler()
df_copy[numerical_columns] = scaler.fit_transform(df_copy[numerical_columns])

# %%
df_copy[numerical_columns]
# Out:
#         Amount       Pop  Households     HH Income  Education Years
# 0     1.769909 -0.588987    0.130678 -2.015035e-01     3.815771e-01
# 1     1.769909 -0.599146    0.085753 -3.631678e-01     3.652358e-01
# 2     1.769909 -0.585939    0.072308 -3.450642e-01     3.193584e-01
# 3     1.769909 -0.588987    0.130678 -2.015035e-01     3.815771e-01
# 4     1.769909 -0.599146    0.085753 -3.631678e-01     3.652358e-01
# ...        ...       ...         ...           ...              ...
# 6285 -0.032859  0.000000    0.000000  6.659371e-16    -1.100888e-15
# 6286 -0.032859  0.000000    0.000000  6.659371e-16    -1.100888e-15
# 6287 -0.039662  0.721287    0.513530  6.194018e-01     4.467634e-02
# 6288 -0.039662  0.577432    0.381213  3.807789e-01     4.593710e-04
# 6289 -0.039662  0.579193    0.350552  3.483577e-01     3.479820e-03
#
# [6290 rows x 5 columns]

# %%
#df_copy = pd.get_dummies(df, columns=['Account Type', 'Stage', 'Masked Primary Campaign'], drop_first=True)
df.columns
# Out:
# Index(['Masked Account ID', 'Maked Primary Campaign', 'Stage', 'Account Type',
#        'Billing Zip/Postal Code', 'Fiscal Period', 'Close Date', 'Amount',
#        'ZCTA', 'Year', 'Pop', 'Households', 'HH Income', 'Education Years',
#        'Minority %', 'Poor %', 'Poor Family %', 'Car or Van %',
#        'Public Transport %', 'Health Ins %', 'No Health Ins %', 'Unemployed %',
#        'Employed %', 'Armed Forces %', 'Not in Labor Force %', 'Under 10 %',
#        'Under 35 %', 'Over 65 %', 'Over 85 %', 'High school %', 'College %',
#        '0-50k %', '50-100k %', '100-150k %', '150-200k %', '200k+ %',
#        'Minority', 'Under 10', 'Under 35', 'Over 65', 'Over 85', 'Male 10-14',
#        'Male 15-17', 'Male 18-19', 'Male 20', 'Male 21', 'Male 22-24',
#        'Male 25-29', 'Male 30-34', 'Female 10-14', 'Female 15-17',
#        'Female 18-19', 'Female 20', 'Female 21', 'Female 22-24',
#        'Female 25-29', 'Female 30-34', 'Ed Pop', 'Less than High School',
#        'High school', 'GED', 'Some college to Associates Degree',
#        'Bachelor's Degree or Higher', '$0-25k', '$25-50k', '$50-75k',
#        '$75-100k', '$100-125k', '$125-150k', '$150-200k', '$200k+',
#        'Poverty Pop', 'Poor', 'Poor Family', 'Transport Pop', 'Car or Van',
#        'Carpool', 'Public Transport', 'Worked from Home', 'Health Ins Pop',
#        'Health Ins', 'No Health Ins', 'Labor Population', 'Armed Forces',
#        'Employed', 'Unemployed', 'Not in Labor Force'],
#       dtype='object')

# %%
conv_to_float = []
for col in df_copy.columns:
    if df_copy[col].dtype == 'object':
        conv_to_float.append(col)

conv_to_float
# Out:
# ['Maked Primary Campaign',
#  'Stage',
#  'Account Type',
#  'Billing Zip/Postal Code',
#  'Fiscal Period',
#  'Close Date',
#  'Minority %',
#  'Poor %',
#  'Poor Family %',
#  'Car or Van %',
#  'Public Transport %',
#  'Health Ins %',
#  'No Health Ins %',
#  'Unemployed %',
#  'Employed %',
#  'Armed Forces %',
#  'Not in Labor Force %',
#  'Under 10 %',
#  'Under 35 %',
#  'Over 65 %',
#  'Over 85 %',
#  'High school %',
#  'College %',
#  '0-50k %',
#  '50-100k %',
#  '100-150k %',
#  '150-200k %',
#  '200k+ %']

# %%
exclude_cols = ['Maked Primary Campaign', 'Stage', 'Account Type', 'Billing Zip/Postal Code', 'Fiscal Period', 'Close Date']
conv_to_float = [col for col in conv_to_float if col not in exclude_cols]

for col in conv_to_float:
    # Replace '#DIV/0!' with NaN first
    df_copy[col] = pd.to_numeric(df_copy[col], errors='coerce')
    
    # Fill NaNs (formerly #DIV/0!) with the mean of the column
    mean_value = df_copy[col].mean()
    df_copy[col] = df_copy[col].fillna(mean_value)
    
    # Convert the column to float
    try:
        df_copy[col] = df_copy[col].astype(float)
        print(f"Column '{col}' successfully converted to float with mean replacement.")
    except ValueError:
        print(f"Column '{col}' could not be converted to float.")
# Out:
# Column 'Minority %' successfully converted to float with mean replacement.
# Column 'Poor %' successfully converted to float with mean replacement.
# Column 'Poor Family %' successfully converted to float with mean replacement.
# Column 'Car or Van %' successfully converted to float with mean replacement.
# Column 'Public Transport %' successfully converted to float with mean replacement.
# Column 'Health Ins %' successfully converted to float with mean replacement.
# Column 'No Health Ins %' successfully converted to float with mean replacement.
# Column 'Unemployed %' successfully converted to float with mean replacement.
# Column 'Employed %' successfully converted to float with mean replacement.
# Column 'Armed Forces %' successfully converted to float with mean replacement.
# Column 'Not in Labor Force %' successfully converted to float with mean replacement.
# Column 'Under 10 %' successfully converted to float with mean replacement.
# Column 'Under 35 %' successfully converted to float with mean replacement.
# Column 'Over 65 %' successfully converted to float with mean replacement.
# Column 'Over 85 %' successfully converted to float with mean replacement.
# Column 'High school %' successfully converted to float with mean replacement.
# Column 'College %' successfully converted to float with mean replacement.
# Column '0-50k %' successfully converted to float with mean replacement.
# Column '50-100k %' successfully converted to float with mean replacement.
# Column '100-150k %' successfully converted to float with mean replacement.
# Column '150-200k %' successfully converted to float with mean replacement.
# Column '200k+ %' successfully converted to float with mean replacement.

# %%
df_copy
# Out:
#       Masked Account ID Maked Primary Campaign       Stage Account Type  \
# 0                     1      Campaign One 2015  Closed Won    Household
# 1                     1      Campaign One 2015  Closed Won    Household
# 2                     1      Campaign One 2015  Closed Won    Household
# 3                     1      Campaign One 2015  Closed Won    Household
# 4                     1      Campaign One 2015  Closed Won    Household
# ...                 ...                    ...         ...          ...
# 6285               1288      Campaign Two 2023  Closed Won    Household
# 6286               1289      Campaign Two 2023  Closed Won    Household
# 6287               1321      Campaign Two 2023  Closed Won    Household
# 6288               1321      Campaign Two 2023  Closed Won    Household
# 6289               1321      Campaign Two 2023  Closed Won    Household
#
#      Billing Zip/Postal Code Fiscal Period Close Date    Amount     ZCTA  \
# 0                      90069       Q3-2022   7/5/2022  1.769909  90069.0
# 1                      90069       Q3-2022   7/5/2022  1.769909  90069.0
# 2                      90069       Q3-2022   7/5/2022  1.769909  90069.0
# 3                      90069       Q3-2023  7/14/2023  1.769909  90069.0
# 4                      90069       Q3-2023  7/14/2023  1.769909  90069.0
# ...                      ...           ...        ...       ...      ...
# 6285                   91105       Q3-2023  7/25/2023 -0.032859  91189.0
# 6286                   90720       Q3-2023  7/29/2023 -0.032859  90721.0
# 6287                   60068       Q3-2023   8/7/2023 -0.039662  60068.0
# 6288                   60068       Q3-2023   8/7/2023 -0.039662  60068.0
# 6289                   60068       Q3-2023   8/7/2023 -0.039662  60068.0
#
#              Year  ...  Worked from Home  Health Ins Pop    Health Ins  \
# 0     2021.000000  ...       3432.000000    20185.000000  19509.000000
# 1     2020.000000  ...       2589.000000    20035.000000  19339.000000
# 2     2019.000000  ...       1963.000000    20230.000000  19348.000000
# 3     2021.000000  ...       3432.000000    20185.000000  19509.000000
# 4     2020.000000  ...       2589.000000    20035.000000  19339.000000
# ...           ...  ...               ...             ...           ...
# 6285  2020.005858  ...       2134.437657    28770.460042  27127.008159
# 6286  2020.005858  ...       2134.437657    28770.460042  27127.008159
# 6287  2021.000000  ...       2921.000000    39109.000000  37940.000000
# 6288  2020.000000  ...       1850.000000    36937.000000  35823.000000
# 6289  2019.000000  ...       1337.000000    36983.000000  35964.000000
#
#       No Health Ins  Labor Population  Armed Forces      Employed  \
# 0        676.000000      19125.000000      0.000000  14080.000000
# 1        696.000000      19017.000000      0.000000  14119.000000
# 2        882.000000      19254.000000      0.000000  14444.000000
# 3        676.000000      19125.000000      0.000000  14080.000000
# 4        696.000000      19017.000000      0.000000  14119.000000
# ...             ...               ...           ...           ...
# 6285    1643.451883      24276.261925     19.048954  15465.512134
# 6286    1643.451883      24276.261925     19.048954  15465.512134
# 6287    1169.000000      31194.000000      0.000000  19684.000000
# 6288    1114.000000      29654.000000      9.000000  18398.000000
# 6289    1019.000000      29667.000000      0.000000  18305.000000
#
#        Unemployed  Not in Labor Force  large_donation_flag
# 0     1124.000000         3921.000000                    1
# 1      910.000000         3988.000000                    1
# 2      738.000000         4072.000000                    1
# 3     1124.000000         3921.000000                    1
# 4      910.000000         3988.000000                    1
# ...           ...                 ...                  ...
# 6285   900.946653         7890.754184                    0
# 6286   900.946653         7890.754184                    0
# 6287   700.000000        10810.000000                    0
# 6288   608.000000        10639.000000                    0
# 6289   552.000000        10810.000000                    0
#
# [6290 rows x 88 columns]

# %%
percentage_columns = [ 'Minority %',
 'Poor %',
 'Poor Family %',
 'Car or Van %',
 'Public Transport %',
 'Health Ins %',
 'No Health Ins %',
 'Unemployed %',
 'Employed %',
 'Armed Forces %',
 'Not in Labor Force %',
 'Under 10 %',
 'Under 35 %',
 'Over 65 %',
 'Over 85 %',
 'High school %',
 'College %',
 '0-50k %',
 '50-100k %',
 '100-150k %',
 '150-200k %',
 '200k+ %']

# %%
correlations = df_copy[['Amount'] + percentage_columns].corr()
correlations
# Out:
#                         Amount  Minority %    Poor %  Poor Family %  \
# Amount                1.000000   -0.012754  0.007311      -0.026157
# Minority %           -0.012754    1.000000  0.600331       0.592879
# Poor %                0.007311    0.600331  1.000000       0.689542
# Poor Family %        -0.026157    0.592879  0.689542       1.000000
# Car or Van %          0.000517   -0.011326 -0.222500       0.072281
# Public Transport %   -0.008576    0.460770  0.395616       0.330539
# Health Ins %          0.000907   -0.583279 -0.636942      -0.699422
# No Health Ins %      -0.000342    0.587700  0.637791       0.699662
# Unemployed %          0.035775    0.468539  0.494172       0.374919
# Employed %            0.050068    0.013928 -0.140449      -0.110752
# Armed Forces %       -0.009392    0.110220  0.016029       0.030431
# Not in Labor Force % -0.050804   -0.049970  0.080428       0.072220
# Under 10 %           -0.082402    0.001434 -0.125335       0.316758
# Under 35 %           -0.024193    0.415793  0.494777       0.321664
# Over 65 %            -0.013827   -0.319327 -0.317262      -0.318832
# Over 85 %            -0.020503   -0.139062 -0.174665      -0.260758
# High school %        -0.008351    0.672679  0.643901       0.869431
# College %             0.005902   -0.655834 -0.610577      -0.827101
# 0-50k %               0.019044    0.622908  0.853401       0.681575
# 50-100k %             0.019428    0.484884  0.401556       0.471984
# 100-150k %            0.012353   -0.016709 -0.348761      -0.326647
# 150-200k %           -0.025477   -0.301837 -0.649871      -0.509515
# 200k+ %              -0.019284   -0.617517 -0.638878      -0.563571
#
#                       Car or Van %  Public Transport %  Health Ins %  \
# Amount                    0.000517           -0.008576      0.000907
# Minority %               -0.011326            0.460770     -0.583279
# Poor %                   -0.222500            0.395616     -0.636942
# Poor Family %             0.072281            0.330539     -0.699422
# Car or Van %              1.000000           -0.509156     -0.119168
# Public Transport %       -0.509156            1.000000     -0.405172
# Health Ins %             -0.119168           -0.405172      1.000000
# No Health Ins %           0.126652            0.405782     -0.999659
# Unemployed %             -0.113997            0.199351     -0.346195
# Employed %                0.018004            0.215881     -0.091357
# Armed Forces %            0.155537            0.040923     -0.098717
# Not in Labor Force %      0.036618           -0.218431      0.104939
# Under 10 %                0.367913           -0.038880     -0.104977
# Under 35 %               -0.178861            0.339392     -0.284763
# Over 65 %                -0.033947           -0.292786      0.358635
# Over 85 %                -0.136835           -0.184668      0.308071
# High school %             0.187299            0.370553     -0.846745
# College %                -0.266210           -0.312179      0.852291
# 0-50k %                  -0.077550            0.391379     -0.786837
# 50-100k %                 0.257437            0.281290     -0.706031
# 100-150k %                0.246971           -0.171536      0.093716
# 150-200k %                0.022131           -0.246096      0.566248
# 200k+ %                  -0.067257           -0.338606      0.789484
#
#                       No Health Ins %  Unemployed %  Employed %  ...  \
# Amount                      -0.000342      0.035775    0.050068  ...
# Minority %                   0.587700      0.468539    0.013928  ...
# Poor %                       0.637791      0.494172   -0.140449  ...
# Poor Family %                0.699662      0.374919   -0.110752  ...
# Car or Van %                 0.126652     -0.113997    0.018004  ...
# Public Transport %           0.405782      0.199351    0.215881  ...
# Health Ins %                -0.999659     -0.346195   -0.091357  ...
# No Health Ins %              1.000000      0.351744    0.086404  ...
# Unemployed %                 0.351744      1.000000    0.122106  ...
# Employed %                   0.086404      0.122106    1.000000  ...
# Armed Forces %               0.102838      0.103925    0.103972  ...
# Not in Labor Force %        -0.098344     -0.247040   -0.985763  ...
# Under 10 %                   0.105292     -0.180296    0.191275  ...
# Under 35 %                   0.281541      0.312233    0.474076  ...
# Over 65 %                   -0.354797     -0.309990   -0.733331  ...
# Over 85 %                   -0.304601     -0.116705   -0.589276  ...
# High school %                0.848515      0.349044   -0.063758  ...
# College %                   -0.855044     -0.357868    0.091724  ...
# 0-50k %                      0.788912      0.473637   -0.131907  ...
# 50-100k %                    0.709192      0.427030    0.388687  ...
# 100-150k %                  -0.089271     -0.107867    0.160039  ...
# 150-200k %                  -0.563969     -0.254689    0.060762  ...
# 200k+ %                     -0.790105     -0.462444   -0.148587  ...
#
#                       Under 35 %  Over 65 %  Over 85 %  High school %  \
# Amount                 -0.024193  -0.013827  -0.020503      -0.008351
# Minority %              0.415793  -0.319327  -0.139062       0.672679
# Poor %                  0.494777  -0.317262  -0.174665       0.643901
# Poor Family %           0.321664  -0.318832  -0.260758       0.869431
# Car or Van %           -0.178861  -0.033947  -0.136835       0.187299
# Public Transport %      0.339392  -0.292786  -0.184668       0.370553
# Health Ins %           -0.284763   0.358635   0.308071      -0.846745
# No Health Ins %         0.281541  -0.354797  -0.304601       0.848515
# Unemployed %            0.312233  -0.309990  -0.116705       0.349044
# Employed %              0.474076  -0.733331  -0.589276      -0.063758
# Armed Forces %          0.107073  -0.145461  -0.121716       0.106123
# Not in Labor Force %   -0.504618   0.749644   0.580989       0.043642
# Under 10 %              0.198559  -0.332767  -0.351923       0.243582
# Under 35 %              1.000000  -0.823961  -0.547956       0.276253
# Over 65 %              -0.823961   1.000000   0.840198      -0.294404
# Over 85 %              -0.547956   0.840198   1.000000      -0.240897
# High school %           0.276253  -0.294404  -0.240897       1.000000
# College %              -0.217829   0.260833   0.223157      -0.981551
# 0-50k %                 0.278937  -0.152756  -0.015410       0.765525
# 50-100k %               0.436936  -0.568688  -0.487254       0.617767
# 100-150k %             -0.047461   0.045220   0.083783      -0.105722
# 150-200k %             -0.274128   0.232279   0.205197      -0.505933
# 200k+ %                -0.372730   0.338839   0.184015      -0.736124
#
#                       College %   0-50k %  50-100k %  100-150k %  150-200k %  \
# Amount                 0.005902  0.019044   0.019428    0.012353   -0.025477
# Minority %            -0.655834  0.622908   0.484884   -0.016709   -0.301837
# Poor %                -0.610577  0.853401   0.401556   -0.348761   -0.649871
# Poor Family %         -0.827101  0.681575   0.471984   -0.326647   -0.509515
# Car or Van %          -0.266210 -0.077550   0.257437    0.246971    0.022131
# Public Transport %    -0.312179  0.391379   0.281290   -0.171536   -0.246096
# Health Ins %           0.852291 -0.786837  -0.706031    0.093716    0.566248
# No Health Ins %       -0.855044  0.788912   0.709192   -0.089271   -0.563969
# Unemployed %          -0.357868  0.473637   0.427030   -0.107867   -0.254689
# Employed %             0.091724 -0.131907   0.388687    0.160039    0.060762
# Armed Forces %        -0.137912  0.076866   0.243904    0.219845   -0.016267
# Not in Labor Force %  -0.072481  0.086396  -0.400111   -0.122257   -0.028857
# Under 10 %            -0.211432 -0.130635   0.047951   -0.062364   -0.088954
# Under 35 %            -0.217829  0.278937   0.436936   -0.047461   -0.274128
# Over 65 %              0.260833 -0.152756  -0.568688    0.045220    0.232279
# Over 85 %              0.223157 -0.015410  -0.487254    0.083783    0.205197
# High school %         -0.981551  0.765525   0.617767   -0.105722   -0.505933
# College %              1.000000 -0.770921  -0.665504    0.031903    0.466030
# 0-50k %               -0.770921  1.000000   0.542978   -0.231695   -0.608122
# 50-100k %             -0.665504  0.542978   1.000000    0.140366   -0.357284
# 100-150k %             0.031903 -0.231695   0.140366    1.000000    0.358431
# 150-200k %             0.466030 -0.608122  -0.357284    0.358431    1.000000
# 200k+ %                0.782237 -0.846445  -0.820342   -0.159780    0.364511
#
#                        200k+ %
# Amount               -0.019284
# Minority %           -0.617517
# Poor %               -0.638878
# Poor Family %        -0.563571
# Car or Van %         -0.067257
# Public Transport %   -0.338606
# Health Ins %          0.789484
# No Health Ins %      -0.790105
# Unemployed %         -0.462444
# Employed %           -0.148587
# Armed Forces %       -0.196065
# Not in Labor Force %  0.185429
# Under 10 %            0.126387
# Under 35 %           -0.372730
# Over 65 %             0.338839
# Over 85 %             0.184015
# High school %        -0.736124
# College %             0.782237
# 0-50k %              -0.846445
# 50-100k %            -0.820342
# 100-150k %           -0.159780
# 150-200k %            0.364511
# 200k+ %               1.000000
#
# [23 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of demographic percentage columns
percentage_columns = [
    'Minority %', 'Poor %', 'Poor Family %', 'Car or Van %', 
    'Public Transport %', 'Health Ins %', 'No Health Ins %', 
    'Unemployed %', 'Employed %', 'Armed Forces %', 'Not in Labor Force %', 
    'Under 10 %', 'Under 35 %', 'Over 65 %', 'Over 85 %', 
    'High school %', 'College %', '0-50k %', '50-100k %', 
    '100-150k %', '150-200k %', '200k+ %'
]

plt.figure(figsize=(20, 20)) 

# Plot scatter plots for each percentage feature vs. donation amount
for i, col in enumerate(percentage_columns, 1):
    plt.subplot(6, 4, i)
    sns.scatterplot(data=df_copy, x=col, y='Amount')
    plt.title(f'Donation Amount vs. {col}')
    plt.xlabel(col)
    plt.ylabel('Donation Amount')

plt.tight_layout()
plt.show()

# %%
df_copy = pd.get_dummies(df_copy, columns=['Account Type', 'Stage', 'Maked Primary Campaign'], drop_first=True)

# %%
# %pip install category_encoders
import category_encoders as ce

# Initialize target encoder for high-cardinality columns
target_encoder = ce.TargetEncoder(cols=['Billing Zip/Postal Code', 'Masked Account ID'])
df_copy[['Billing Zip/Postal Code', 'Masked Account ID']] = target_encoder.fit_transform(df_copy[['Billing Zip/Postal Code', 'Masked Account ID']], df_copy['Amount'])
# Out:
# Requirement already satisfied: category_encoders in /Users/jc/predborrowersenv/lib/python3.12/site-packages (2.6.4)
# Requirement already satisfied: numpy>=1.14.0 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from category_encoders) (2.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from category_encoders) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from category_encoders) (1.14.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: pandas>=1.0.5 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Requirement already satisfied: six>=1.5 in /Users/jc/predborrowersenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df_copy
# Out:
#       Masked Account ID  Billing Zip/Postal Code Fiscal Period Close Date  \
# 0              3.713661                 2.337194       Q3-2022   7/5/2022
# 1              3.713661                 2.337194       Q3-2022   7/5/2022
# 2              3.713661                 2.337194       Q3-2022   7/5/2022
# 3              3.713661                 2.337194       Q3-2023  7/14/2023
# 4              3.713661                 2.337194       Q3-2023  7/14/2023
# ...                 ...                      ...           ...        ...
# 6285          -0.004275                -0.008042       Q3-2023  7/25/2023
# 6286          -0.004275                -0.004275       Q3-2023  7/29/2023
# 6287          -0.006126                -0.006126       Q3-2023   8/7/2023
# 6288          -0.006126                -0.006126       Q3-2023   8/7/2023
# 6289          -0.006126                -0.006126       Q3-2023   8/7/2023
#
#         Amount     ZCTA         Year       Pop  Households     HH Income  ...  \
# 0     1.769909  90069.0  2021.000000 -0.588987    0.130678 -2.015035e-01  ...
# 1     1.769909  90069.0  2020.000000 -0.599146    0.085753 -3.631678e-01  ...
# 2     1.769909  90069.0  2019.000000 -0.585939    0.072308 -3.450642e-01  ...
# 3     1.769909  90069.0  2021.000000 -0.588987    0.130678 -2.015035e-01  ...
# 4     1.769909  90069.0  2020.000000 -0.599146    0.085753 -3.631678e-01  ...
# ...        ...      ...          ...       ...         ...           ...  ...
# 6285 -0.032859  91189.0  2020.005858  0.000000    0.000000  6.659371e-16  ...
# 6286 -0.032859  90721.0  2020.005858  0.000000    0.000000  6.659371e-16  ...
# 6287 -0.039662  60068.0  2021.000000  0.721287    0.513530  6.194018e-01  ...
# 6288 -0.039662  60068.0  2020.000000  0.577432    0.381213  3.807789e-01  ...
# 6289 -0.039662  60068.0  2019.000000  0.579193    0.350552  3.483577e-01  ...
#
#       Stage_In-Kind Received  Maked Primary Campaign_Campaign One 2015  \
# 0                      False                                      True
# 1                      False                                      True
# 2                      False                                      True
# 3                      False                                      True
# 4                      False                                      True
# ...                      ...                                       ...
# 6285                   False                                     False
# 6286                   False                                     False
# 6287                   False                                     False
# 6288                   False                                     False
# 6289                   False                                     False
#
#       Maked Primary Campaign_Campaign One 2016  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2017  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2018  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2019  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2020  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2021  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2022  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2023
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                      True
# 6286                                      True
# 6287                                      True
# 6288                                      True
# 6289                                      True
#
# [6290 rows x 98 columns]

# %%
df_copy['Close Date'] = pd.to_datetime(df_copy['Close Date'])
df_copy['Close Year'] = df_copy['Close Date'].dt.year
df_copy['Close Month'] = df_copy['Close Date'].dt.month
df_copy['Close DayOfWeek'] = df_copy['Close Date'].dt.dayofweek

# %%
df_copy
# Out:
#       Masked Account ID  Billing Zip/Postal Code Fiscal Period Close Date  \
# 0              3.713661                 2.337194       Q3-2022 2022-07-05
# 1              3.713661                 2.337194       Q3-2022 2022-07-05
# 2              3.713661                 2.337194       Q3-2022 2022-07-05
# 3              3.713661                 2.337194       Q3-2023 2023-07-14
# 4              3.713661                 2.337194       Q3-2023 2023-07-14
# ...                 ...                      ...           ...        ...
# 6285          -0.004275                -0.008042       Q3-2023 2023-07-25
# 6286          -0.004275                -0.004275       Q3-2023 2023-07-29
# 6287          -0.006126                -0.006126       Q3-2023 2023-08-07
# 6288          -0.006126                -0.006126       Q3-2023 2023-08-07
# 6289          -0.006126                -0.006126       Q3-2023 2023-08-07
#
#         Amount     ZCTA         Year       Pop  Households     HH Income  ...  \
# 0     1.769909  90069.0  2021.000000 -0.588987    0.130678 -2.015035e-01  ...
# 1     1.769909  90069.0  2020.000000 -0.599146    0.085753 -3.631678e-01  ...
# 2     1.769909  90069.0  2019.000000 -0.585939    0.072308 -3.450642e-01  ...
# 3     1.769909  90069.0  2021.000000 -0.588987    0.130678 -2.015035e-01  ...
# 4     1.769909  90069.0  2020.000000 -0.599146    0.085753 -3.631678e-01  ...
# ...        ...      ...          ...       ...         ...           ...  ...
# 6285 -0.032859  91189.0  2020.005858  0.000000    0.000000  6.659371e-16  ...
# 6286 -0.032859  90721.0  2020.005858  0.000000    0.000000  6.659371e-16  ...
# 6287 -0.039662  60068.0  2021.000000  0.721287    0.513530  6.194018e-01  ...
# 6288 -0.039662  60068.0  2020.000000  0.577432    0.381213  3.807789e-01  ...
# 6289 -0.039662  60068.0  2019.000000  0.579193    0.350552  3.483577e-01  ...
#
#       Maked Primary Campaign_Campaign Two 2017  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2018  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2019  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2020  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2021  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2022  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6285                                     False
# 6286                                     False
# 6287                                     False
# 6288                                     False
# 6289                                     False
#
#       Maked Primary Campaign_Campaign Two 2023  Close Year  Close Month  \
# 0                                        False        2022            7
# 1                                        False        2022            7
# 2                                        False        2022            7
# 3                                        False        2023            7
# 4                                        False        2023            7
# ...                                        ...         ...          ...
# 6285                                      True        2023            7
# 6286                                      True        2023            7
# 6287                                      True        2023            8
# 6288                                      True        2023            8
# 6289                                      True        2023            8
#
#       Close DayOfWeek
# 0                   1
# 1                   1
# 2                   1
# 3                   4
# 4                   4
# ...               ...
# 6285                1
# 6286                5
# 6287                0
# 6288                0
# 6289                0
#
# [6290 rows x 101 columns]

# %%
df_copy = df_copy[df_copy['Amount'] >= 0]

# %%
for col, dtype in df_copy.dtypes.items():
    if dtype == 'object':
        print(f"Column: {col}, Data Type: {dtype}")
# Out:
# Column: Fiscal Period, Data Type: object

# %%
df['Fiscal Period'].head()
# Out:
# 0    Q3-2022
# 1    Q3-2022
# 2    Q3-2022
# 3    Q3-2023
# 4    Q3-2023
# Name: Fiscal Period, dtype: object

# %%
# If Masked Account ID appears more than once, label as 1 (repeat donor), else 0

# Create a new column 'repeat_donor' with the binary label
df_copy['repeat_donor'] = df_copy.groupby('Masked Account ID')['Masked Account ID'].transform('count') > 1
df_copy['repeat_donor'] = df_copy['repeat_donor'].astype(int)  # Convert boolean to integer (1 for repeat, 0 for single-time)

# Verify labels
print(df_copy[['Masked Account ID', 'repeat_donor']].drop_duplicates().sort_values(by='Masked Account ID'))
# Out:
#       Masked Account ID  repeat_donor
# 1852          -0.027674             1
# 1824          -0.026839             1
# 63            -0.024500             1
# 4199          -0.021114             1
# 202           -0.020670             1
# ...                 ...           ...
# 1829           0.042625             1
# 45             0.080418             1
# 535            0.114618             1
# 1661           0.219624             1
# 0              3.713661             1
#
# [66 rows x 2 columns]
# /var/folders/tc/7f3jbxgx52j_3w8yhjydvzh00000gn/T/ipykernel_71684/1217284805.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['repeat_donor'] = df_copy.groupby('Masked Account ID')['Masked Account ID'].transform('count') > 1
# /var/folders/tc/7f3jbxgx52j_3w8yhjydvzh00000gn/T/ipykernel_71684/1217284805.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy['repeat_donor'] = df_copy['repeat_donor'].astype(int)  # Convert boolean to integer (1 for repeat, 0 for single-time)

# %%
from sklearn.ensemble import RandomForestClassifier  # Use Classifier instead of Regressor for binary target
from sklearn.feature_selection import RFE
import pandas as pd

# Define model as RandomForestClassifier for binary target
estimator = RandomForestClassifier(random_state=42)

# Initialize RFE with the estimator
rfe = RFE(estimator=estimator, n_features_to_select=10)  # Select top 10 features, adjust as needed

# Prepare X by dropping target and irrelevant columns
# Drop Masked Account ID and other irrelevant columns for modeling
X = df_copy.drop(columns=['Amount', 'Masked Account ID', 'repeat_donor', 'Close Date', 'Fiscal Period'])

# Convert datetime columns to useful numeric features
if 'Close Date' in X.columns:
    X['Close Year'] = pd.to_datetime(X['Close Date']).dt.year
    X['Close Month'] = pd.to_datetime(X['Close Date']).dt.month
    X['Close DayOfWeek'] = pd.to_datetime(X['Close Date']).dt.dayofweek
    
    # Drop the original datetime column
    X = X.drop(columns=['Close Date'])

# Define the target variable
y = df_copy['repeat_donor']

# Fit RFE
rfe.fit(X, y)

# Get selected features
selected_features = X.columns[rfe.support_]
print("Selected Features:", selected_features)
# Out:
# Selected Features: Index(['Billing Zip/Postal Code', 'ZCTA', 'Education Years', 'High school %',
#        'Less than High School', 'large_donation_flag',
#        'Account Type_Household', 'Close Year', 'Close Month',
#        'Close DayOfWeek'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, precision_recall_curve
import matplotlib.pyplot as plt

# %%
# Define X and y based on your selected features
X = df_copy[['Billing Zip/Postal Code', 'ZCTA', 'Education Years', 'High school %',
             'large_donation_flag', 'Account Type_Household', 
             'Maked Primary Campaign_Campaign One 2015', 
             'Close Year', 'Close Month', 'Close DayOfWeek']]
y = df_copy['repeat_donor']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Check the distribution of classes in the training set
print(y_train.value_counts())

# For a more readable output with percentages
print(y_train.value_counts(normalize=True) * 100)
# Out:
# repeat_donor
# 1    425
# 0      6
# Name: count, dtype: int64
# repeat_donor
# 1    98.607889
# 0     1.392111
# Name: proportion, dtype: float64

# %%
# Parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize Random Forest with RandomizedSearchCV
rf_model = RandomForestClassifier(random_state=42)
rf_search = RandomizedSearchCV(estimator=rf_model, param_distributions=param_grid_rf,
                               n_iter=20, cv=5, scoring='f1', random_state=42, n_jobs=-1)

# Fit RandomizedSearchCV
rf_search.fit(X_train, y_train)

# Get best model from RandomizedSearchCV
best_rf_model = rf_search.best_estimator_
print("Best Random Forest Parameters:", rf_search.best_params_)
# Out:
# Best Random Forest Parameters: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True}

# %%
# Predictions and probabilities
y_pred = best_rf_model.predict(X_test)
y_pred_proba = best_rf_model.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate metrics
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_proba)

# Print metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("AUC-ROC:", auc_roc)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Precision: 0.9783783783783784
# Recall: 1.0
# F1-Score: 0.9890710382513661
# AUC-ROC: 0.8812154696132597
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.98      1.00      0.99       181
#
#     accuracy                           0.98       185
#    macro avg       0.49      0.50      0.49       185
# weighted avg       0.96      0.98      0.97       185
# /Users/jc/predborrowersenv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/jc/predborrowersenv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/jc/predborrowersenv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Plot ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_roc:.2f}')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Precision-Recall Curve
precision_vals, recall_vals, _ = precision_recall_curve(y_test, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(recall_vals, precision_vals)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# apply SMOTE to the training data only
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# check new distribution of the training labels after SMOTE
print("Training label distribution after SMOTE:")
print(y_train_resampled.value_counts())

# initialize and train the model with class weighting
model = RandomForestClassifier(random_state=42, class_weight='balanced')
model.fit(X_train_resampled, y_train_resampled)

# make predictions on the test data
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

# evaluate the model!
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("AUC-ROC:", roc_auc_score(y_test, y_pred_proba))
# Out:
# Training label distribution after SMOTE:
# repeat_donor
# 1    425
# 0    425
# Name: count, dtype: int64
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.98      0.99      0.99       181
#
#     accuracy                           0.97       185
#    macro avg       0.49      0.50      0.49       185
# weighted avg       0.96      0.97      0.96       185
#
# AUC-ROC: 0.9516574585635359
